# %%
from src.visualization import base_plots_bokeh as bp

# %%
import pandas as pd

# %%
df = pd.DataFrame({'a': [10], 'b':[20]})

# %%
len(['bathroom', 'bedroom', 'dining_room' 
                              'frontyard', 'kitchen', 'living_room'])
# Out:
# 5

# %% [markdown]
# ### Vision based dataset

# %%
df = pd.DataFrame({'escena': ['bathroom', 'bedroom', 'dining_room',
                              'frontyard', 'kitchen', 'living_room'], 
                   'cantidad':[10058, 24123, 19500, 24869, 24234, 24210,]})

# %%
bp.plot_bar(df['escena'], df['cantidad'],
    y_label='Cantidad de imágenes',
    y_err=None,
    title='Vision Based Real Estate Price Estimation Dataset - Imágenes por categoría',
    figsize=None,
    tooltips=None,
    multiple_plots=False,
    y_range_end=None,
    plot_height=None,
)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f7de6197-a530-4070-91eb-d818773e0805" data-root-id="1003"></div>

# %% [markdown]
# ### REI dataset

# %%
df = pd.DataFrame({'escena': ['backyard', 'bathroom', 'bedroom', 
                              'frontyard', 'kitchen', 'living_room'], 
                   'cantidad':[745, 793, 1593, 884, 992, 852]})

# %%
bp.plot_bar(df['escena'], df['cantidad'],
    y_label='Cantidad de imágenes',
    y_err=None,
    title='Real Estate Images Dataset - Imágenes por categoría',
    figsize=None,
    tooltips=None,
    multiple_plots=False,
    y_range_end=None,
    plot_height=None,
)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1201">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="02667773-7a93-4a47-a007-ce4fc5fbad4a" data-root-id="1203"></div>

# %% [markdown]
# ### Exp 2 datasets

# %%
df = pd.DataFrame({
    'porcentaje': [10, 10, 10, 10, 10, 10, 50, 50, 50, 50, 50, 50, 
                   100, 100, 100, 100, 100, 100],
    'escena': ['bathroom', 'bedroom', 'dining_room',
               'frontyard', 'kitchen', 'living_room',
              'bathroom', 'bedroom', 'dining_room',
               'frontyard', 'kitchen', 'living_room',
              'bathroom', 'bedroom', 'dining_room',
               'frontyard', 'kitchen', 'living_room',], 
    'cantidad':[877, 2067, 1662, 2129, 2074, 2084,
                3588, 8513, 6897, 8748, 8620, 8607,
                9088, 21710, 17534, 22359, 21848, 21822]})

# %%
df.groupby(['porcentaje',]).size().reset_index().T
# Out:
#              0   1    2
# porcentaje  10  50  100
# 0            6   6    6

# %% [markdown]
# ### Exp 2 validation and test

# %%
df = pd.DataFrame({
    'escena': ['bathroom', 'bedroom', 'dining_room',
               'frontyard', 'kitchen', 'living_room',], 
    'cantidad_valid':[480, 1240, 966, 1249, 1176, 1194,],
    'cantidad_test':[490, 1173, 1000, 1261, 1210, 1194],})

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llr}
# \toprule
# {} &       escena &  cantidad \\
# \midrule
# 0 &     backyard &       745 \\
# 1 &     bathroom &       793 \\
# 2 &      bedroom &      1593 \\
# 3 &    frontyard &       884 \\
# 4 &      kitchen &       992 \\
# 5 &  living\_room &       852 \\
# \bottomrule
# \end{tabular}

# %%
\begin{tabular}{llrr}
\toprule
Escena &  Cantidad de Imágenes &  Cantidad de Imágenes \\
{} & para validación & para verificación \\
\midrule
bathroom &             480 &            490 \\
bedroom &            1240 &           1173 \\
dining\_room &             966 &           1000 \\
frontyard &            1249 &           1261 \\
kitchen &            1176 &           1210 \\
living\_room &            1194 &           1194 \\
\bottomrule
\end{tabular}
# Out:
#   File "<ipython-input-21-2bac1b666faf>", line 1
#     \begin{tabular}{lrlr}
#                          ^
# SyntaxError: unexpected character after line continuation character

# %%
\begin{tabular}{lrlr}
\toprule
Porcentaje & Escena &  Cantidad \\
subconjunto & {} &  de Imágenes \\
\midrule
10 &     bathroom &       877 \\
10 &      bedroom &      2067 \\
10 &  dining\_room &      1662 \\
10 &    frontyard &      2129 \\
10 &      kitchen &      2074 \\
10 &  living\_room &      2084 \\
50 &     bathroom &      3588 \\
50 &      bedroom &      8513 \\
50 &  dining\_room &      6897 \\
50 &    frontyard &      8748 \\
50 &      kitchen &      8620 \\
50 &  living\_room &      8607 \\
\bottomrule
\end{tabular}

# %%
bp.plot_bar(['a','b'], [10, 20])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b76c280c-a381-497d-8577-a285dac91f25" data-root-id="1003"></div>
