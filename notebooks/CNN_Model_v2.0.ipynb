# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

tf.keras.backend.clear_session()

# %%
from src.models import base_model, cnn_model
from src import custom_losses, custom_metrics, optimizers
from src.data import data
# Out:
# Using TensorFlow backend.

# %%
from importlib import reload

# %%
batch_size = 64
n_classes = 6
epochs = 100
# img_size = 256
img_size = 64
n_channels = 3
steps_per_epoch = 4700
validation_steps = int(steps_per_epoch*0.1 )

# %%
paths = data.PATH()

# %%
dataset_path = f'{paths.PROCESSED_DATA_PATH}/REI-Dataset/'

# %%
model = cnn_model.CNN_Model(batch_size, n_classes, epochs, img_size, n_channels)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1116 18:19:12.046941 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1116 18:19:12.055908 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1116 18:19:12.065303 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1116 18:19:12.105862 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1116 18:19:12.106647 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1116 18:19:13.042853 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W1116 18:19:13.213797 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W1116 18:19:13.223811 139840986511168 deprecation.py:506] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
train_generator, validation_generator = model.get_image_data_generator(dataset_path, train=True, validation=True)
weights = model.get_class_weights(train_generator.classes, model)
model.compile(loss=custom_losses.weighted_categorical_crossentropy(weights), metrics=['categorical_accuracy'],)
# Out:
# Found 4747 images belonging to 6 classes.
# Found 527 images belonging to 6 classes.
# W1116 18:19:13.959450 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        2432
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 60, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 32)        25632
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        51264
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 64)        102464
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 20, 20, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1638656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 1,822,758
# Trainable params: 1,822,374
# Non-trainable params: 384
# _________________________________________________________________

# %%
# keras.backend.get_session().run(tf.global_variables_initializer())

# %%
model.fit_from_generator(path=dataset_path, train_steps_per_epoch=steps_per_epoch, validation_steps_per_epoch=validation_steps, 
                         train_generator=train_generator, validation_generator=validation_generator, evaluate_net=True, use_model_check_point=False)
# Out:
# W1116 18:19:17.229585 139840986511168 deprecation.py:323] From /home/ifranco/Documents/facultad/tesis/tesis_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 4700/4700 [==============================] - 1096s 233ms/step - loss: 0.2444 - categorical_accuracy: 0.9057 - val_loss: 1.4601 - val_categorical_accuracy: 0.7800
# Epoch 2/100
# 4700/4700 [==============================] - 1206s 257ms/step - loss: 0.0539 - categorical_accuracy: 0.9817 - val_loss: 3.4306 - val_categorical_accuracy: 0.5748
# Epoch 3/100
# 4700/4700 [==============================] - 1209s 257ms/step - loss: 0.0359 - categorical_accuracy: 0.9888 - val_loss: 1.3195 - val_categorical_accuracy: 0.8234
# Epoch 4/100
# 4700/4700 [==============================] - 1211s 258ms/step - loss: 0.0284 - categorical_accuracy: 0.9915 - val_loss: 1.4303 - val_categorical_accuracy: 0.7986
# Epoch 5/100
# 4700/4700 [==============================] - 1209s 257ms/step - loss: 0.0240 - categorical_accuracy: 0.9929 - val_loss: 1.8284 - val_categorical_accuracy: 0.7911
# Epoch 6/100
# 4700/4700 [==============================] - 1211s 258ms/step - loss: 0.0195 - categorical_accuracy: 0.9946 - val_loss: 1.3554 - val_categorical_accuracy: 0.8406
# Epoch 7/100
# 4700/4700 [==============================] - 1215s 259ms/step - loss: 0.0175 - categorical_accuracy: 0.9952 - val_loss: 1.6303 - val_categorical_accuracy: 0.8083
# Epoch 8/100
# 4700/4700 [==============================] - 1210s 257ms/step - loss: 0.0154 - categorical_accuracy: 0.9957 - val_loss: 2.1105 - val_categorical_accuracy: 0.7838
# weights [1.27607527 1.31861111 0.59936869 1.08378995 0.98526359 1.17383778]
# W1116 20:58:45.346074 139840986511168 deprecation_wrapper.py:119] From /home/ifranco/Documents/facultad/tesis/tf_real_estate_images_classification/src/models/base_model.py:94: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
# Found 585 images belonging to 6 classes.
# Scores: [1.8455266204654661, 0.15726496]
# Found 585 images belonging to 6 classes.

# %%
model.pred
# Out:
# [('bedroom', 0.17941648),
#  ('bedroom', 0.18258129),
#  ('bathroom', 0.18082014),
#  ('bathroom', 0.18391141),
#  ('bathroom', 0.18289983),
#  ('bedroom', 0.17564331),
#  ('bathroom', 0.18547173),
#  ('bathroom', 0.17674215),
#  ('bathroom', 0.18185961),
#  ('bathroom', 0.1845109),
#  ('bathroom', 0.17912816),
#  ('bathroom', 0.17815328),
#  ('bathroom', 0.18285353),
#  ('livingRoom', 0.17762396),
#  ('bathroom', 0.18185881),
#  ('bathroom', 0.17605074),
#  ('bathroom', 0.1813973),
#  ('bathroom', 0.18691088),
#  ('bathroom', 0.1828577),
#  ('bathroom', 0.18002929),
#  ('bathroom', 0.17635123),
#  ('bathroom', 0.18171754),
#  ('bedroom', 0.1795212),
#  ('bedroom', 0.17094356),
#  ('bathroom', 0.17704085),
#  ('bathroom', 0.18395919),
#  ('bathroom', 0.17831159),
#  ('bathroom', 0.18100764),
#  ('bathroom', 0.17944455),
#  ('bathroom', 0.1810937),
#  ('bathroom', 0.18249),
#  ('bathroom', 0.17549916),
#  ('bathroom', 0.17883135),
#  ('bedroom', 0.17814705),
#  ('bathroom', 0.18543442),
#  ('bathroom', 0.18354473),
#  ('bedroom', 0.18011035),
#  ('bathroom', 0.17977245),
#  ('bathroom', 0.17982815),
#  ('bathroom', 0.18058488),
#  ('bathroom', 0.1807746),
#  ('bathroom', 0.18178552),
#  ('bathroom', 0.18102291),
#  ('bathroom', 0.18474847),
#  ('bedroom', 0.17615919),
#  ('bathroom', 0.18469381),
#  ('livingRoom', 0.17583312),
#  ('bathroom', 0.17888547),
#  ('bathroom', 0.17674269),
#  ('bedroom', 0.17835352),
#  ('bathroom', 0.18295068),
#  ('bathroom', 0.18277118),
#  ('bathroom', 0.18851665),
#  ('bathroom', 0.18103537),
#  ('bedroom', 0.17980069),
#  ('bathroom', 0.17913397),
#  ('bathroom', 0.1834717),
#  ('bathroom', 0.18268989),
#  ('bathroom', 0.18266752),
#  ('bathroom', 0.18141897),
#  ('bathroom', 0.18160395),
#  ('bedroom', 0.17374721),
#  ('bathroom', 0.18017018),
#  ('bedroom', 0.17536269),
#  ('bedroom', 0.1762955),
#  ('bathroom', 0.18224119),
#  ('bathroom', 0.18198511),
#  ('bedroom', 0.1796561),
#  ('bathroom', 0.18806006),
#  ('bathroom', 0.18281096),
#  ('bedroom', 0.1765209),
#  ('bathroom', 0.18011506),
#  ('bedroom', 0.18090771),
#  ('bathroom', 0.17913947),
#  ('bathroom', 0.1802708),
#  ('bedroom', 0.1775588),
#  ('bathroom', 0.1843181),
#  ('bathroom', 0.18343094),
#  ('bathroom', 0.18316554),
#  ('bathroom', 0.17895299),
#  ('bathroom', 0.18082407),
#  ('bathroom', 0.18511572),
#  ('bathroom', 0.18191464),
#  ('bathroom', 0.18267637),
#  ('bedroom', 0.18003002),
#  ('bathroom', 0.18172216),
#  ('bathroom', 0.1835115),
#  ('bathroom', 0.18207602),
#  ('bathroom', 0.17868204),
#  ('bathroom', 0.17858608),
#  ('bathroom', 0.1820564),
#  ('bathroom', 0.18439561),
#  ('bathroom', 0.186806),
#  ('bathroom', 0.17827176),
#  ('bathroom', 0.18528147),
#  ('bathroom', 0.1848763),
#  ('bathroom', 0.1807543),
#  ('bathroom', 0.1759092),
#  ('bathroom', 0.18103883),
#  ('bathroom', 0.1823255),
#  ('bathroom', 0.18372695),
#  ('bathroom', 0.186577),
#  ('bedroom', 0.18696731),
#  ('bedroom', 0.17818135),
#  ('bathroom', 0.18284357),
#  ('bathroom', 0.17946455),
#  ('bathroom', 0.18805076),
#  ('bathroom', 0.1858894),
#  ('bedroom', 0.17524995),
#  ('bathroom', 0.18351907),
#  ('bathroom', 0.18647477),
#  ('bathroom', 0.18761149),
#  ('bathroom', 0.1913467),
#  ('bathroom', 0.17713599),
#  ('bathroom', 0.18915199),
#  ('bathroom', 0.18202011),
#  ('bathroom', 0.18553236),
#  ('bathroom', 0.18971173),
#  ('bathroom', 0.17975682),
#  ('bathroom', 0.1768364),
#  ('bathroom', 0.18503305),
#  ('bathroom', 0.18327522),
#  ('bathroom', 0.17903484),
#  ('bathroom', 0.18743525),
#  ('bathroom', 0.18331175),
#  ('bathroom', 0.18774208),
#  ('bathroom', 0.18261483),
#  ('bathroom', 0.18030243),
#  ('bedroom', 0.1812759),
#  ('bathroom', 0.18007484),
#  ('bathroom', 0.18576156),
#  ('bedroom', 0.17883152),
#  ('bathroom', 0.17659119),
#  ('bathroom', 0.17855462),
#  ('bedroom', 0.17871699),
#  ('bathroom', 0.18237774),
#  ('bedroom', 0.17854679),
#  ('bathroom', 0.18081968),
#  ('bedroom', 0.18316583),
#  ('bathroom', 0.18448454),
#  ('bathroom', 0.18673679),
#  ('bathroom', 0.18940747),
#  ('bathroom', 0.18222065),
#  ('bathroom', 0.17925817),
#  ('bathroom', 0.18346134),
#  ('bedroom', 0.1779473),
#  ('bedroom', 0.18005908),
#  ('bedroom', 0.18255647),
#  ('bathroom', 0.18376179),
#  ('bathroom', 0.18626486),
#  ('bedroom', 0.182879),
#  ('bathroom', 0.18020943),
#  ('bedroom', 0.18310684),
#  ('bedroom', 0.182107),
#  ('bedroom', 0.17904095),
#  ('bathroom', 0.18034774),
#  ('bathroom', 0.18484639),
#  ('bedroom', 0.18255451),
#  ('bathroom', 0.17932688),
#  ('bedroom', 0.17513782),
#  ('bedroom', 0.18052174),
#  ('bedroom', 0.18139195),
#  ('bathroom', 0.18220939),
#  ('bathroom', 0.18137321),
#  ('bathroom', 0.18218654),
#  ('bathroom', 0.18545528),
#  ('bathroom', 0.18023632),
#  ('bathroom', 0.1861413),
#  ('bathroom', 0.1779884),
#  ('bedroom', 0.1787275),
#  ('bathroom', 0.18434092),
#  ('bathroom', 0.18108691),
#  ('bathroom', 0.18482053),
#  ('bathroom', 0.1832225),
#  ('bathroom', 0.18900298),
#  ('bathroom', 0.17827217),
#  ('bathroom', 0.18862876),
#  ('bathroom', 0.17792971),
#  ('bathroom', 0.17946744),
#  ('bathroom', 0.18347184),
#  ('bathroom', 0.18728726),
#  ('bathroom', 0.18450564),
#  ('bathroom', 0.17965014),
#  ('bathroom', 0.17975734),
#  ('bedroom', 0.18502587),
#  ('bathroom', 0.17920795),
#  ('bedroom', 0.17652489),
#  ('bathroom', 0.17807168),
#  ('bathroom', 0.1822818),
#  ('bedroom', 0.17447084),
#  ('bathroom', 0.17798428),
#  ('bathroom', 0.17593344),
#  ('bathroom', 0.18034306),
#  ('bathroom', 0.18188226),
#  ('bathroom', 0.18097134),
#  ('bathroom', 0.18224578),
#  ('bathroom', 0.18311375),
#  ('bathroom', 0.18144277),
#  ('bathroom', 0.1828964),
#  ('bathroom', 0.18256032),
#  ('bedroom', 0.17673536),
#  ('bathroom', 0.18582089),
#  ('bathroom', 0.1804509),
#  ('bathroom', 0.1810802),
#  ('bathroom', 0.18148364),
#  ('bathroom', 0.18671618),
#  ('bathroom', 0.18143138),
#  ('bathroom', 0.18508993),
#  ('bedroom', 0.18157981),
#  ('bathroom', 0.17830592),
#  ('bathroom', 0.18164305),
#  ('bedroom', 0.1767754),
#  ('bathroom', 0.17554139),
#  ('bedroom', 0.18028487),
#  ('bathroom', 0.17814595),
#  ('bathroom', 0.17460753),
#  ('bathroom', 0.18090877),
#  ('bathroom', 0.18004866),
#  ('bathroom', 0.18513994),
#  ('bathroom', 0.18889724),
#  ('bathroom', 0.182839),
#  ('bedroom', 0.17852907),
#  ('livingRoom', 0.17841922),
#  ('bathroom', 0.18362646),
#  ('bathroom', 0.18436459),
#  ('bathroom', 0.18397377),
#  ('bathroom', 0.17695709),
#  ('bedroom', 0.178373),
#  ('bathroom', 0.19135688),
#  ('bathroom', 0.18189082),
#  ('bathroom', 0.17945544),
#  ('livingRoom', 0.17869236),
#  ('bedroom', 0.17637728),
#  ('bathroom', 0.17608134),
#  ('bathroom', 0.17880706),
#  ('bathroom', 0.18320823),
#  ('bathroom', 0.17890364),
#  ('livingRoom', 0.17597365),
#  ('bedroom', 0.18379718),
#  ('bathroom', 0.17552799),
#  ('bedroom', 0.17830499),
#  ('bedroom', 0.17548032),
#  ('bathroom', 0.17929453),
#  ('bathroom', 0.18542983),
#  ('bathroom', 0.17784339),
#  ('bedroom', 0.17597026),
#  ('bedroom', 0.17564051),
#  ('bathroom', 0.17496924),
#  ('bathroom', 0.1776708),
#  ('bathroom', 0.18088722),
#  ('bathroom', 0.179696),
#  ('bedroom', 0.17967635),
#  ('bedroom', 0.17826842),
#  ('bathroom', 0.17882238),
#  ('bathroom', 0.18150069),
#  ('bedroom', 0.18104135),
#  ('bathroom', 0.18115097),
#  ('bedroom', 0.17859027),
#  ('bathroom', 0.18377939),
#  ('bedroom', 0.18002836),
#  ('bedroom', 0.17810325),
#  ('bathroom', 0.17571735),
#  ('bathroom', 0.17676446),
#  ('bathroom', 0.17811137),
#  ('bathroom', 0.18039651),
#  ('bathroom', 0.1802492),
#  ('bathroom', 0.1794984),
#  ('bathroom', 0.18379964),
#  ('bathroom', 0.18880038),
#  ('bathroom', 0.17827706),
#  ('bathroom', 0.18174174),
#  ('bathroom', 0.17713067),
#  ('bathroom', 0.18508628),
#  ('bathroom', 0.18153088),
#  ('bathroom', 0.18442155),
#  ('bathroom', 0.17420837),
#  ('bathroom', 0.18978335),
#  ('bathroom', 0.1819997),
#  ('bathroom', 0.18064763),
#  ('bathroom', 0.17546326),
#  ('bedroom', 0.18041925),
#  ('bathroom', 0.18009536),
#  ('bathroom', 0.18039598),
#  ('bathroom', 0.18077321),
#  ('bedroom', 0.17809905),
#  ('bedroom', 0.18097387),
#  ('bathroom', 0.17666617),
#  ('bedroom', 0.17553854),
#  ('bathroom', 0.1806216),
#  ('bedroom', 0.17803721),
#  ('bathroom', 0.17614189),
#  ('bathroom', 0.18294963),
#  ('bathroom', 0.18167616),
#  ('bathroom', 0.1748992),
#  ('bathroom', 0.18168564),
#  ('bedroom', 0.18172896),
#  ('bathroom', 0.18297447),
#  ('bedroom', 0.1744602),
#  ('bathroom', 0.1843977),
#  ('bedroom', 0.1819533),
#  ('bathroom', 0.18169194),
#  ('bedroom', 0.17855336),
#  ('bathroom', 0.18239267),
#  ('bedroom', 0.18080956),
#  ('bathroom', 0.18054588),
#  ('bathroom', 0.17800437),
#  ('bedroom', 0.18244864),
#  ('bathroom', 0.17655326),
#  ('bathroom', 0.17919771),
#  ('bathroom', 0.17927673),
#  ('bathroom', 0.18369605),
#  ('bathroom', 0.17873152),
#  ('bathroom', 0.18805523),
#  ('bathroom', 0.18009146),
#  ('bathroom', 0.18158673),
#  ('bedroom', 0.17340066),
#  ('bathroom', 0.18660365),
#  ('bathroom', 0.18233971),
#  ('bathroom', 0.18253571),
#  ('bathroom', 0.17858243),
#  ('bathroom', 0.17995259),
#  ('bathroom', 0.17876855),
#  ('bathroom', 0.17926371),
#  ('bathroom', 0.18137424),
#  ('bathroom', 0.18819094),
#  ('bedroom', 0.18007305),
#  ('bathroom', 0.1823906),
#  ('bedroom', 0.17929135),
#  ('bedroom', 0.18154122),
#  ('bathroom', 0.18651146),
#  ('bathroom', 0.18143831),
#  ('bathroom', 0.18442124),
#  ('bathroom', 0.1833741),
#  ('bathroom', 0.18904066),
#  ('bedroom', 0.178366),
#  ('bathroom', 0.18499146),
#  ('bathroom', 0.18295905),
#  ('bedroom', 0.17543602),
#  ('bathroom', 0.17911325),
#  ('bathroom', 0.18413702),
#  ('bedroom', 0.1771283),
#  ('livingRoom', 0.17754287),
#  ('bathroom', 0.18279444),
#  ('bathroom', 0.18168586),
#  ('bathroom', 0.1865396),
#  ('bathroom', 0.17531045),
#  ('bathroom', 0.1794362),
#  ('bathroom', 0.17998572),
#  ('bathroom', 0.18054654),
#  ('bathroom', 0.18782939),
#  ('bedroom', 0.18321976),
#  ('bathroom', 0.17920259),
#  ('bathroom', 0.18003133),
#  ('bathroom', 0.17866145),
#  ('bedroom', 0.18066764),
#  ('bathroom', 0.18444534),
#  ('bedroom', 0.18217753),
#  ('bathroom', 0.17593022),
#  ('bathroom', 0.1788281),
#  ('bedroom', 0.1786808),
#  ('bathroom', 0.18159598),
#  ('bathroom', 0.18345994),
#  ('bathroom', 0.1805591),
#  ('bathroom', 0.18500096),
#  ('bathroom', 0.1823721),
#  ('bathroom', 0.18419848),
#  ('bathroom', 0.18712051),
#  ('bathroom', 0.18010256),
#  ('bedroom', 0.17881063),
#  ('bathroom', 0.17979069),
#  ('bathroom', 0.18080892),
#  ('bathroom', 0.18218823),
#  ('bathroom', 0.18079561),
#  ('bathroom', 0.18149352),
#  ('bathroom', 0.17804088),
#  ('bathroom', 0.18307054),
#  ('bathroom', 0.18582658),
#  ('bathroom', 0.18167406),
#  ('bathroom', 0.18069452),
#  ('bathroom', 0.17786986),
#  ('bedroom', 0.1807111),
#  ('bathroom', 0.18623562),
#  ('bathroom', 0.18352267),
#  ('bathroom', 0.17881192),
#  ('bedroom', 0.17863284),
#  ('bathroom', 0.17682824),
#  ('bathroom', 0.1819167),
#  ('bathroom', 0.18450323),
#  ('bathroom', 0.17866382),
#  ('bedroom', 0.1815644),
#  ('bathroom', 0.18083276),
#  ('bathroom', 0.17828438),
#  ('bathroom', 0.17744705),
#  ('bedroom', 0.18129537),
#  ('bathroom', 0.18058904),
#  ('bathroom', 0.17952363),
#  ('bedroom', 0.18027887),
#  ('bathroom', 0.1795546),
#  ('bathroom', 0.18251365),
#  ('bedroom', 0.18224882),
#  ('bathroom', 0.18629697),
#  ('bedroom', 0.17593656),
#  ('bathroom', 0.18462373),
#  ('bathroom', 0.18463661),
#  ('bathroom', 0.18117884),
#  ('bathroom', 0.18469785),
#  ('bathroom', 0.18144736),
#  ('bathroom', 0.17604527),
#  ('bathroom', 0.17992312),
#  ('bathroom', 0.18514816),
#  ('bathroom', 0.17906035),
#  ('bedroom', 0.17841735),
#  ('bathroom', 0.17919128),
#  ('bathroom', 0.18242341),
#  ('bathroom', 0.17770791),
#  ('bedroom', 0.17654583),
#  ('bedroom', 0.17610154),
#  ('bathroom', 0.18340693),
#  ('bathroom', 0.18000619),
#  ('bathroom', 0.18806998),
#  ('bathroom', 0.18891409),
#  ('bedroom', 0.18352002),
#  ('bathroom', 0.17892572),
#  ('bathroom', 0.18225172),
#  ('bathroom', 0.18287137),
#  ('bedroom', 0.18293273),
#  ('bathroom', 0.18121894),
#  ('bathroom', 0.17823853),
#  ('bathroom', 0.18175493),
#  ('bathroom', 0.17898837),
#  ('bathroom', 0.17920074),
#  ('bathroom', 0.18502842),
#  ('bathroom', 0.1834192),
#  ('bathroom', 0.18101686),
#  ('bathroom', 0.18123679),
#  ('bathroom', 0.18086654),
#  ('bathroom', 0.18086834),
#  ('bedroom', 0.18071643),
#  ('bedroom', 0.18089966),
#  ('bedroom', 0.18042484),
#  ('bedroom', 0.17709237),
#  ('bathroom', 0.1798503),
#  ('bathroom', 0.18182296),
#  ('bedroom', 0.17655584),
#  ('bathroom', 0.18388924),
#  ('bathroom', 0.17862998),
#  ('bathroom', 0.17770234),
#  ('bathroom', 0.18314138),
#  ('bathroom', 0.18666255),
#  ('bathroom', 0.17809391),
#  ('bedroom', 0.1843014),
#  ('bathroom', 0.17381972),
#  ('bathroom', 0.18896997),
#  ('bathroom', 0.1810397),
#  ('bathroom', 0.17879835),
#  ('bathroom', 0.17922649),
#  ('bathroom', 0.1819807),
#  ('bedroom', 0.18323714),
#  ('bathroom', 0.18233997),
#  ('bedroom', 0.18043378),
#  ('bathroom', 0.17730127),
#  ('bathroom', 0.18356198),
#  ('bathroom', 0.1792809),
#  ('bedroom', 0.1820284),
#  ('bathroom', 0.1814054),
#  ('bathroom', 0.18357481),
#  ('bathroom', 0.18950498),
#  ('bedroom', 0.17654696),
#  ('bathroom', 0.1860426),
#  ('bathroom', 0.18321988),
#  ('bathroom', 0.18010361),
#  ('bathroom', 0.18377957),
#  ('bathroom', 0.1800717),
#  ('bedroom', 0.18181813),
#  ('bathroom', 0.18592033),
#  ('bathroom', 0.1869761),
#  ('bedroom', 0.1799841),
#  ('bedroom', 0.17747723),
#  ('bathroom', 0.18379192),
#  ('bathroom', 0.18725125),
#  ('bathroom', 0.18312453),
#  ('bathroom', 0.182866),
#  ('bathroom', 0.18233116),
#  ('bathroom', 0.17499253),
#  ('bedroom', 0.18201306),
#  ('bathroom', 0.1843965),
#  ('bathroom', 0.179857),
#  ('bedroom', 0.18006942),
#  ('bathroom', 0.17722678),
#  ('bedroom', 0.17479074),
#  ('bathroom', 0.18339339),
#  ('bathroom', 0.18560681),
#  ('bedroom', 0.17858416),
#  ('bedroom', 0.17759125),
#  ('bathroom', 0.1890843),
#  ('bathroom', 0.19129293),
#  ('bathroom', 0.18273132),
#  ('bedroom', 0.18145192),
#  ('bathroom', 0.18859044),
#  ('bathroom', 0.18081276),
#  ('bathroom', 0.18239433),
#  ('bathroom', 0.17980462),
#  ('bedroom', 0.17746499),
#  ('bathroom', 0.18123987),
#  ('bathroom', 0.17992748),
#  ('bathroom', 0.1754065),
#  ('bathroom', 0.18415476),
#  ('bathroom', 0.18189563),
#  ('bathroom', 0.1771681),
#  ('bathroom', 0.17927766),
#  ('bathroom', 0.1791405),
#  ('bathroom', 0.17857732),
#  ('bathroom', 0.17929773),
#  ('bedroom', 0.18136683),
#  ('bathroom', 0.18286078),
#  ('bathroom', 0.18250483),
#  ('bathroom', 0.17965071),
#  ('bathroom', 0.17989118),
#  ('bedroom', 0.17902675),
#  ('bathroom', 0.18325946),
#  ('bedroom', 0.17946947),
#  ('bedroom', 0.18147755),
#  ('bedroom', 0.18100803),
#  ('bathroom', 0.18306924),
#  ('bathroom', 0.1798138),
#  ('bathroom', 0.1801568),
#  ('bathroom', 0.1829079),
#  ('bathroom', 0.18725498),
#  ('bedroom', 0.17563647),
#  ('bathroom', 0.17974146),
#  ('bathroom', 0.17917144),
#  ('bathroom', 0.18192105),
#  ('bedroom', 0.18238589),
#  ('bathroom', 0.18297277),
#  ('bedroom', 0.17809674),
#  ('bathroom', 0.18673067),
#  ('bathroom', 0.18443654),
#  ('bathroom', 0.18192212),
#  ('bathroom', 0.18058611),
#  ('bathroom', 0.18257414),
#  ('bathroom', 0.18053746),
#  ('bathroom', 0.18318239),
#  ('bathroom', 0.18561004),
#  ('bathroom', 0.1793445),
#  ('bathroom', 0.18612319),
#  ('bathroom', 0.18367022),
#  ('bathroom', 0.17972791),
#  ('bathroom', 0.17891733),
#  ('bathroom', 0.18036346),
#  ('bedroom', 0.17509611),
#  ('bathroom', 0.18001296),
#  ('bathroom', 0.18043531),
#  ('bedroom', 0.17738165),
#  ('bedroom', 0.18025023),
#  ('bedroom', 0.18149859),
#  ('bathroom', 0.1782024),
#  ('bathroom', 0.18139279),
#  ('bathroom', 0.18262804),
#  ('bathroom', 0.1833765),
#  ('bathroom', 0.18230736),
#  ('bathroom', 0.1855495),
#  ('bathroom', 0.18594065),
#  ('bathroom', 0.17965938),
#  ('bathroom', 0.18389459),
#  ('bedroom', 0.18332694),
#  ('bathroom', 0.1817978),
#  ('bedroom', 0.18136609),
#  ('livingRoom', 0.18380679),
#  ('bathroom', 0.18181859),
#  ('bathroom', 0.18317272),
#  ('bathroom', 0.18019989),
#  ('bedroom', 0.17692775),
#  ('bathroom', 0.17839615),
#  ('bathroom', 0.1800208),
#  ('bathroom', 0.18397956),
#  ('bathroom', 0.18754083),
#  ('bathroom', 0.17863272),
#  ('bathroom', 0.18150444),
#  ('bathroom', 0.17654349),
#  ('bathroom', 0.18000591),
#  ('bedroom', 0.17935978),
#  ('bathroom', 0.17855962),
#  ('bathroom', 0.18601014),
#  ('bathroom', 0.18723027),
#  ('bathroom', 0.17907391)]

# %%
model.model_path

# %%
# !ls '/home/ifranco/Documents/facultad/tesis/tf_real_estate_images_classification//models/MLP_Model/2019-11-16__18_00/'
# Out:
# weights-improvement-05-13.87.hdf5  weights-improvement-10-13.86.hdf5

# %%
model.scores

# %%
m = model.load_model(model.model_path)

# %%
m.evaluate_from_generator(dataset_path)
