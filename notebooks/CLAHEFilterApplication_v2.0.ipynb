# %%
from src import clahe_filter

# %%
image_path = '../data/processed/vision_based_dataset/train/frontyard/00000009.jpg'

# %%
from matplotlib import pyplot as plt

# %%
w=256
h=256
fig=plt.figure(figsize=(20, 20))
columns = 2
rows = 1

img = plt.imread(image_path)
fig.add_subplot(rows, columns, 1)
plt.imshow(img)

result = clahe_filter.make_clahe(img, clip_limit=2.5)
fig.add_subplot(rows, columns, 2)
plt.imshow(result)
plt.show()
